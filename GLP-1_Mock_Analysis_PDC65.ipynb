# %% [markdown]
# Imports packages and connection to internal Actuary Team database

# %%
import pandas as pd
import pyodbc
connection_string = ("DRIVER={SQL Server};"
"SERVER=USDF11V0954;"
"DATABASE=Actuarial_AH;"
"Trust_Connection=yes;")

conn = pyodbc.connect(connection_string)
cursor = conn.cursor()

# %% [markdown]
# Runs SQL query that creates a cohort of individuals that had a script for Wegovy, Saxenda, or Zepbound between service dates 2022 and 2025. Using that cohort, returns medical claims dataset that were paid between 2021 and 2025 and were actively enrolled since 2021.

# %%
med = """
WITH WEIGHTLOSSCOHORT1 AS (
    SELECT DISTINCT MEMBER_ID,
           YEAR(SERVICE_DATE) AS PRESCRIPTION_YEAR
    FROM Actuarial_AH.DBO.SN_Rx
    WHERE DRUG_NAME_PREFERRED IN ('Wegovy', 'Saxenda', 'Zepbound')
    AND SERVICE_DATE >= '2022-01-01'
    AND SERVICE_DATE < '2025-01-01'
)
SELECT M.MEDICAL_CLAIM_ID, 
       M.MEMBER_ID, 
       M.PAID_DATE, 
	   YEAR(M.PAID_DATE) AS PAID_YEAR,
       M.SERVICE_DATE,
YEAR(M.SERVICE_DATE) AS SERVICE_YEAR,
       M.MEDICAL_PAID_AMOUNT, 
       M.IS_TELEMEDICINE, 
       M.IS_ER_AVOIDABLE, 
M.DIAGNOSIS_DESC_ICD10_1 AS PRIMARY_DX,
       M.PROCEDURE_DESC, 
       M.ARTTOS_V2_L1, 
       M.ARTTOS_V2_L3, 
M.DX_IS_CHRONIC,
       M.ICD10_CHAPTER, 
       M.ICD10_CATEGORY, 
       M.ICD10_SECTION, 
       M.MEG_EPISODE_DESCRIPTION, 
       M.OP_SURG_INC,
       M.IS_PCP_VISIT, 
       M.INCLUDED_SPECIALIST, 
       M.ER_VISIT_FLAG, 
       M.IS_URGENT_CARE_VISIT, 
       M.IS_PREVENTIVE_VISIT, 
       M.IP_ADMIT_INC
FROM [Actuarial_AH].[dbo].[SN_Medical] M
JOIN 
Actuarial_AH.dbo.SN_Member MB ON M.MEMBER_ID = MB.MEMBER_ID
WHERE M.PAID_DATE BETWEEN '2021-01-01' AND '2024-12-31'
AND MB.MONTH_KEY = '2024-12-01' 
AND MB.MEDICAL_ENROLLMENT_STATUS = 3
AND MB.MEDICAL_CONT_ENRLMNT_START <= '2021-01-01'
AND MB.MEMBER_ID IN (
    SELECT MEMBER_ID
    FROM WEIGHTLOSSCOHORT1
    GROUP BY MEMBER_ID
	)
"""
med = pd.read_sql(med, conn)
# Out:
# C:\Users\U1229773\AppData\Local\Temp\ipykernel_30428\2598388549.py:49: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   med = pd.read_sql(med, conn)

# %%
#create mock claims dataset to replace company data
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random

# Set seed for reproducibility
np.random.seed(42)

# Parameters
num_records = 100000
num_members = 10000

# Generate member IDs (weight loss cohort)
member_ids = np.random.choice(range(10000, 20000), size=num_members, replace=False)
selected_member_ids = np.random.choice(member_ids, size=num_records, replace=True)

# Generate random dates between 2021 and 2024
def random_date(start, end):
    return start + timedelta(days=random.randint(0, (end - start).days))

start_date = datetime(2021, 1, 1)
end_date = datetime(2024, 12, 31)
paid_dates = [random_date(start_date, end_date) for _ in range(num_records)]
service_dates = [random_date(start_date, end_date) for _ in range(num_records)]

# Claim IDs
medical_claim_ids = np.arange(1, num_records + 1)

# Amounts and binary flags
medical_paid_amounts = np.round(np.random.exponential(scale=200, size=num_records), 2)
bool_choices = [0, 1]

# Text-based columns (mocked)
diagnosis_desc = np.random.choice(['Obesity', 'Type 2 Diabetes', 'Hypertension', 'Hyperlipidemia'], size=num_records)
procedure_desc = np.random.choice(['Office Visit', 'Lab Test', 'Imaging', 'Bariatric Surgery'], size=num_records)
arttos_l1 = np.random.choice(['Evaluation & Management', 'Surgery', 'Radiology'], size=num_records)
arttos_l3 = np.random.choice(['Office Visit', 'Major Surgery', 'Outpatient Imaging'], size=num_records)
icd10_chapter = np.random.choice(['Endocrine', 'Circulatory', 'Digestive'], size=num_records)
icd10_category = np.random.choice(['E11', 'I10', 'K21'], size=num_records)
icd10_section = np.random.choice(['E11.9', 'I10.0', 'K21.9'], size=num_records)
meg_description = np.random.choice(['Diabetes Management', 'Obesity Treatment', 'Routine Checkup'], size=num_records)

# Create DataFrame
med = pd.DataFrame({
    'MEDICAL_CLAIM_ID': medical_claim_ids,
    'MEMBER_ID': selected_member_ids,
    'PAID_DATE': paid_dates,
    'PAID_YEAR': [d.year for d in paid_dates],
    'SERVICE_DATE': service_dates,
    'SERVICE_YEAR': [d.year for d in service_dates],
    'MEDICAL_PAID_AMOUNT': medical_paid_amounts,
    'IS_TELEMEDICINE': np.random.choice(bool_choices, size=num_records),
    'IS_ER_AVOIDABLE': np.random.choice(bool_choices, size=num_records),
    'PRIMARY_DX': diagnosis_desc,
    'PROCEDURE_DESC': procedure_desc,
    'ARTTOS_V2_L1': arttos_l1,
    'ARTTOS_V2_L3': arttos_l3,
    'DX_IS_CHRONIC': np.random.choice(bool_choices, size=num_records),
    'ICD10_CHAPTER': icd10_chapter,
    'ICD10_CATEGORY': icd10_category,
    'ICD10_SECTION': icd10_section,
    'MEG_EPISODE_DESCRIPTION': meg_description,
    'OP_SURG_INC': np.random.choice(bool_choices, size=num_records),
    'IS_PCP_VISIT': np.random.choice(bool_choices, size=num_records),
    'INCLUDED_SPECIALIST': np.random.choice(bool_choices, size=num_records),
    'ER_VISIT_FLAG': np.random.choice(bool_choices, size=num_records),
    'IS_URGENT_CARE_VISIT': np.random.choice(bool_choices, size=num_records),
    'IS_PREVENTIVE_VISIT': np.random.choice(bool_choices, size=num_records),
    'IP_ADMIT_INC': np.random.choice(bool_choices, size=num_records)
})

med.head()
# Out:
#    MEDICAL_CLAIM_ID  MEMBER_ID  PAID_DATE  PAID_YEAR SERVICE_DATE  \
# 0                 1      18180 2021-07-20       2021   2024-01-01
# 1                 2      13277 2021-08-25       2021   2024-06-25
# 2                 3      12610 2021-05-29       2021   2022-10-04
# 3                 4      18708 2022-04-21       2022   2024-12-14
# 4                 5      16682 2023-06-23       2023   2024-09-16
#
#    SERVICE_YEAR  MEDICAL_PAID_AMOUNT  IS_TELEMEDICINE  IS_ER_AVOIDABLE  \
# 0          2024               116.36                1                0
# 1          2024                96.93                0                1
# 2          2022                92.08                0                0
# 3          2024               256.49                1                0
# 4          2024               141.06                1                0
#
#        PRIMARY_DX  ... ICD10_CATEGORY ICD10_SECTION MEG_EPISODE_DESCRIPTION  \
# 0  Hyperlipidemia  ...            I10         E11.9         Routine Checkup
# 1  Hyperlipidemia  ...            K21         E11.9     Diabetes Management
# 2    Hypertension  ...            I10         E11.9       Obesity Treatment
# 3    Hypertension  ...            K21         I10.0     Diabetes Management
# 4  Hyperlipidemia  ...            I10         I10.0     Diabetes Management
#
#    OP_SURG_INC IS_PCP_VISIT INCLUDED_SPECIALIST ER_VISIT_FLAG  \
# 0            1            1                   0             0
# 1            1            1                   0             0
# 2            0            1                   0             0
# 3            1            1                   1             0
# 4            0            0                   0             0
#
#   IS_URGENT_CARE_VISIT  IS_PREVENTIVE_VISIT  IP_ADMIT_INC
# 0                    1                    1             1
# 1                    0                    1             1
# 2                    1                    0             1
# 3                    0                    0             0
# 4                    1                    0             0
#
# [5 rows x 25 columns]

# %% [markdown]
# Runs SQL query that creates a cohort of individuals that had a script for Wegovy, Saxenda, or Zepbound between service dates 2022 and 2025. Using that cohort, returns pharmacy claims dataset that were paid between 2021 and 2025 and were actively enrolled since 2021.

# %%
rx = """
WITH WEIGHTLOSSCOHORT1 AS (
    SELECT DISTINCT MEMBER_ID,
           YEAR(SERVICE_DATE) AS PRESCRIPTION_YEAR
    FROM Actuarial_AH.DBO.SN_Rx
    WHERE DRUG_NAME_PREFERRED IN ('Wegovy', 'Saxenda', 'Zepbound')
    AND SERVICE_DATE BETWEEN '2022-01-01' AND '2024-12-31'
)
SELECT R.RX_CLAIM_ID, 
       R.MEMBER_ID, 
       R.PAID_DATE,
       R.DAYS,
       R.SERVICE_DATE, 
       R.DRUG_NAME_GENERIC,
	   R.DRUG_NAME_PREFERRED,
	   R.RX_PAID_AMOUNT,
	   R.RX_SCRIPT_COUNT,
	   R.ART_DRUGGRPS_L1,
	   R.ART_DRUGGRPS_L2,
	   YEAR(R.PAID_DATE) AS PAID_YEAR,
YEAR(R.SERVICE_DATE) AS SERVICE_YEAR
FROM [Actuarial_AH].[dbo].[SN_Rx] R
JOIN 
Actuarial_AH.dbo.SN_Member M ON R.MEMBER_ID = M.MEMBER_ID
WHERE R.PAID_DATE BETWEEN '2021-01-01' AND '2024-12-31'
AND M.MONTH_KEY = '2024-12-01' 
AND M.MEDICAL_ENROLLMENT_STATUS = 3
AND M.MEDICAL_CONT_ENRLMNT_START <= '2021-01-01'
AND M.MEMBER_ID IN (
    SELECT MEMBER_ID
    FROM WEIGHTLOSSCOHORT1
    GROUP BY MEMBER_ID
	)
"""
rx = pd.read_sql(rx, conn)
# Out:
# C:\Users\U1229773\AppData\Local\Temp\ipykernel_30428\3517386714.py:36: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rx = pd.read_sql(rx, conn)

# %%
# Set seed for reproducibility
np.random.seed(42)

# Use the same MEMBER_IDs as the medical dataset (assumed already created)
# Simulate cohort of members
rx_member_ids = np.random.choice(range(10000, 20000), size=10000, replace=False)
num_rx_records = 100000
selected_rx_member_ids = np.random.choice(rx_member_ids, size=num_rx_records, replace=True)

# Date range
start_date = datetime(2021, 1, 1)
end_date = datetime(2024, 12, 31)

def random_date(start, end):
    return start + timedelta(days=random.randint(0, (end - start).days))

rx_paid_dates = [random_date(start_date, end_date) for _ in range(num_rx_records)]
rx_service_dates = [random_date(datetime(2022, 1, 1), datetime(2024, 12, 31)) for _ in range(num_rx_records)]

# Random drug assignment (cohort drugs + others)
cohort_drugs = [
    ('semaglutide', 'Wegovy'),
    ('liraglutide', 'Saxenda'),
    ('tirzepatide', 'Zepbound')
]

other_drugs = [
    ('metformin', 'Glucophage'),
    ('atorvastatin', 'Lipitor'),
    ('lisinopril', 'Prinivil'),
    ('amlodipine', 'Norvasc'),
    ('hydrochlorothiazide', 'Microzide'),
    ('levothyroxine', 'Synthroid'),
    ('albuterol', 'Ventolin'),
]

# Mix 60% cohort drugs, 40% other
cohort_size = int(num_rx_records * 0.6)
other_size = num_rx_records - cohort_size
drug_mix = random.choices(cohort_drugs, k=cohort_size) + random.choices(other_drugs, k=other_size)
random.shuffle(drug_mix)  # Shuffle to mix cohort and non-cohort drugs

generic_names, preferred_names = zip(*drug_mix)

# Other fields
rx_claim_ids = np.arange(1, num_rx_records + 1)
rx_days = np.random.choice([30, 60, 90], size=num_rx_records)
rx_paid_amounts = np.round(np.random.exponential(scale=150, size=num_rx_records), 2)
rx_script_counts = np.random.choice([1, 2, 3], size=num_rx_records)
art_druggrps_l1 = np.random.choice(['Antidiabetics', 'Obesity Agents', 'Antihypertensives', 'Respiratory Agents'], size=num_rx_records)
art_druggrps_l2 = np.random.choice(['GLP-1 Agonists', 'ACE Inhibitors', 'Beta Blockers', 'Inhalers'], size=num_rx_records)

# Build DataFrame
rx = pd.DataFrame({
    'RX_CLAIM_ID': rx_claim_ids,
    'MEMBER_ID': selected_rx_member_ids,
    'PAID_DATE': rx_paid_dates,
    'DAYS': rx_days,
    'SERVICE_DATE': rx_service_dates,
    'DRUG_NAME_GENERIC': generic_names,
    'DRUG_NAME_PREFERRED': preferred_names,
    'RX_PAID_AMOUNT': rx_paid_amounts,
    'RX_SCRIPT_COUNT': rx_script_counts,
    'ART_DRUGGRPS_L1': art_druggrps_l1,
    'ART_DRUGGRPS_L2': art_druggrps_l2,
    'PAID_YEAR': [d.year for d in rx_paid_dates],
    'SERVICE_YEAR': [d.year for d in rx_service_dates]
})

# Preview
rx.head()
# Out:
#    RX_CLAIM_ID  MEMBER_ID  PAID_DATE  DAYS SERVICE_DATE    DRUG_NAME_GENERIC  \
# 0            1      18180 2023-02-10    60   2023-01-25  hydrochlorothiazide
# 1            2      13277 2021-08-29    30   2024-07-10          semaglutide
# 2            3      12610 2024-12-02    60   2023-12-13          semaglutide
# 3            4      18708 2024-11-15    60   2022-11-03  hydrochlorothiazide
# 4            5      16682 2024-06-27    30   2024-12-28           amlodipine
#
#   DRUG_NAME_PREFERRED  RX_PAID_AMOUNT  RX_SCRIPT_COUNT    ART_DRUGGRPS_L1  \
# 0           Microzide           31.73                3      Antidiabetics
# 1              Wegovy           11.59                1     Obesity Agents
# 2              Wegovy           46.64                2     Obesity Agents
# 3           Microzide           43.10                3     Obesity Agents
# 4             Norvasc          131.72                2  Antihypertensives
#
#   ART_DRUGGRPS_L2  PAID_YEAR  SERVICE_YEAR
# 0  ACE Inhibitors       2023          2023
# 1  ACE Inhibitors       2021          2024
# 2  ACE Inhibitors       2024          2023
# 3   Beta Blockers       2024          2022
# 4  ACE Inhibitors       2024          2024

# %% [markdown]
# Runs SQL query that creates a cohort of individuals that had a script for Wegovy, Saxenda, or Zepbound between service dates 2022 and 2025. Using that cohort, returns unique members dataset that were actively enrolled since 2021.

# %%
member = """
WITH WEIGHTLOSSCOHORT1 AS (
    SELECT DISTINCT MEMBER_ID,
           YEAR(SERVICE_DATE) AS PRESCRIPTION_YEAR
    FROM Actuarial_AH.DBO.SN_Rx
    WHERE DRUG_NAME_PREFERRED IN ('Wegovy', 'Saxenda', 'Zepbound')
    AND SERVICE_DATE >= '2022-01-01'
    AND SERVICE_DATE < '2025-01-01'
)
SELECT M.MEMBER_ID,
       M.MEMBER_STATUS,
       M.HOME_STATE,
	   CASE 
    WHEN M.MEMBER_RELATIONSHIP = 0 THEN 'Subscriber'
    WHEN M.MEMBER_RELATIONSHIP = 1 THEN 'Spouse'
    WHEN M.MEMBER_RELATIONSHIP = 2 THEN 'Dependent'
    WHEN M.MEMBER_RELATIONSHIP = 3 THEN 'Domestic Partner'
    WHEN M.MEMBER_RELATIONSHIP = 4 THEN 'Unknown'
    ELSE 'Unknown' -- Optional: Handle unexpected values
END AS MEMBER_RELATIONSHIP,
CASE 
        WHEN M.GENDER = 0 THEN 'Female'
        WHEN M.GENDER = 1 THEN 'Male'
        WHEN M.GENDER = 2 THEN 'Unknown'
        ELSE 'Unknown' 
    END AS GENDER,
    DATEDIFF(YEAR, CONVERT(DATE, M.BIRTH_YEAR_MO + '-01'), GETDATE()) - 
    CASE 
        WHEN MONTH(CONVERT(DATE, M.BIRTH_YEAR_MO + '-01')) > MONTH(GETDATE()) 
             OR (MONTH(CONVERT(DATE, M.BIRTH_YEAR_MO + '-01')) = MONTH(GETDATE()) 
                 AND DAY(CONVERT(DATE, M.BIRTH_YEAR_MO + '-01')) > DAY(GETDATE())) 
        THEN 1 
        ELSE 0 
    END AS Age,
	CASE 
    WHEN M.BIRTH_YEAR >= 1946 AND M.BIRTH_YEAR < 1965 THEN 'Baby Boomers'
	WHEN M.BIRTH_YEAR >= 1965 AND M.BIRTH_YEAR < 1981 THEN 'Generation X'
	WHEN M.BIRTH_YEAR >= 1981 AND M.BIRTH_YEAR < 1997 THEN 'Millenials'
	WHEN M.BIRTH_YEAR >= 1997 AND M.BIRTH_YEAR < 2012 THEN 'Generation Z'
    ELSE 'Unknown' -- Optional: Handle unexpected values
END AS GENERATIONS
FROM [Actuarial_AH].[dbo].[SN_MEMBER] M
WHERE M.MEMBER_ID IN (
    SELECT MEMBER_ID
    FROM WEIGHTLOSSCOHORT1
    GROUP BY MEMBER_ID
	)
AND M.MONTH_KEY = '2024-12-01' 
AND M.MEDICAL_ENROLLMENT_STATUS = 3
AND M.MEDICAL_CONT_ENRLMNT_START <= '2021-01-01'
"""
member = pd.read_sql(member, conn)
# Out:
# C:\Users\U1229773\AppData\Local\Temp\ipykernel_30428\1131752232.py:55: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   member = pd.read_sql(member, conn)

# %%
# Set seed for reproducibility
np.random.seed(42)

# Assume these MEMBER_IDs come from your medical/pharmacy datasets
member_ids = np.random.choice(range(10000, 20000), size=10000, replace=False)
num_members = len(member_ids)

# Mock MEMBER_STATUS (1 = active, 2 = COBRA, 3 = retired)
member_status = np.random.choice([1, 2, 3], size=num_members)

# HOME_STATE (US states)
states = ['UT', 'CA', 'TX', 'NY', 'FL', 'WA', 'IL', 'CO', 'PA', 'NC']
home_states = np.random.choice(states, size=num_members)

# MEMBER_RELATIONSHIP codes
relationship_codes = np.random.choice([0, 1, 2, 3, 4], size=num_members)
relationship_map = {
    0: 'Subscriber',
    1: 'Spouse',
    2: 'Dependent',
    3: 'Domestic Partner',
    4: 'Unknown'
}
relationship_labels = [relationship_map[r] for r in relationship_codes]

# GENDER codes
genders = np.random.choice([0, 1, 2], size=num_members)
gender_map = {
    0: 'Female',
    1: 'Male',
    2: 'Unknown'
}
gender_labels = [gender_map[g] for g in genders]

# BIRTH_YEAR_MO generation
birth_years = np.random.choice(range(1946, 2012), size=num_members)
birth_months = np.random.choice(range(1, 13), size=num_members)
birth_year_mo = [f"{y}-{m:02d}" for y, m in zip(birth_years, birth_months)]

# Age calculation as of June 28, 2025
ref_date = datetime(2025, 6, 28)
ages = []
generations = []

for year, month in zip(birth_years, birth_months):
    dob = datetime(year, month, 1)
    age = ref_date.year - dob.year - ((ref_date.month, ref_date.day) < (dob.month, dob.day))
    ages.append(age)

    if 1946 <= year < 1965:
        generations.append('Baby Boomers')
    elif 1965 <= year < 1981:
        generations.append('Generation X')
    elif 1981 <= year < 1997:
        generations.append('Millenials')
    elif 1997 <= year < 2012:
        generations.append('Generation Z')
    else:
        generations.append('Unknown')

# Create DataFrame
member = pd.DataFrame({
    'MEMBER_ID': member_ids,
    'MEMBER_STATUS': member_status,
    'HOME_STATE': home_states,
    'MEMBER_RELATIONSHIP': relationship_labels,
    'GENDER': gender_labels,
    'Age': ages,
    'GENERATIONS': generations
})

# Preview
member.head()
# Out:
#    MEMBER_ID  MEMBER_STATUS HOME_STATE MEMBER_RELATIONSHIP   GENDER  Age  \
# 0      16252              2         CA          Subscriber     Male   56
# 1      14684              3         NC    Domestic Partner     Male   73
# 2      11731              2         WA              Spouse  Unknown   71
# 3      14742              3         FL          Subscriber   Female   55
# 4      14521              1         FL          Subscriber  Unknown   39
#
#     GENERATIONS
# 0  Generation X
# 1  Baby Boomers
# 2  Baby Boomers
# 3  Generation X
# 4    Millenials

# %% [markdown]
# Reviewing medical, pharmacy and member tables

# %%
med
# Out:
#        MEDICAL_CLAIM_ID  MEMBER_ID  PAID_DATE  PAID_YEAR SERVICE_DATE  \
# 0                     1      18180 2021-07-20       2021   2024-01-01
# 1                     2      13277 2021-08-25       2021   2024-06-25
# 2                     3      12610 2021-05-29       2021   2022-10-04
# 3                     4      18708 2022-04-21       2022   2024-12-14
# 4                     5      16682 2023-06-23       2023   2024-09-16
# ...                 ...        ...        ...        ...          ...
# 99995             99996      12607 2022-05-18       2022   2023-07-02
# 99996             99997      14528 2021-10-26       2021   2023-07-07
# 99997             99998      14138 2023-12-10       2023   2022-08-30
# 99998             99999      16528 2021-07-30       2021   2022-05-19
# 99999            100000      15894 2023-02-12       2023   2022-12-19
#
#        SERVICE_YEAR  MEDICAL_PAID_AMOUNT  IS_TELEMEDICINE  IS_ER_AVOIDABLE  \
# 0              2024               116.36                1                0
# 1              2024                96.93                0                1
# 2              2022                92.08                0                0
# 3              2024               256.49                1                0
# 4              2024               141.06                1                0
# ...             ...                  ...              ...              ...
# 99995          2023                44.26                1                1
# 99996          2023                69.52                1                1
# 99997          2022               426.73                1                1
# 99998          2022                83.67                0                1
# 99999          2022               144.81                0                0
#
#             PRIMARY_DX  ... ICD10_CATEGORY ICD10_SECTION  \
# 0       Hyperlipidemia  ...            I10         E11.9
# 1       Hyperlipidemia  ...            K21         E11.9
# 2         Hypertension  ...            I10         E11.9
# 3         Hypertension  ...            K21         I10.0
# 4       Hyperlipidemia  ...            I10         I10.0
# ...                ...  ...            ...           ...
# 99995     Hypertension  ...            K21         I10.0
# 99996  Type 2 Diabetes  ...            E11         E11.9
# 99997  Type 2 Diabetes  ...            I10         K21.9
# 99998          Obesity  ...            I10         E11.9
# 99999          Obesity  ...            I10         K21.9
#
#       MEG_EPISODE_DESCRIPTION  OP_SURG_INC IS_PCP_VISIT INCLUDED_SPECIALIST  \
# 0             Routine Checkup            1            1                   0
# 1         Diabetes Management            1            1                   0
# 2           Obesity Treatment            0            1                   0
# 3         Diabetes Management            1            1                   1
# 4         Diabetes Management            0            0                   0
# ...                       ...          ...          ...                 ...
# 99995       Obesity Treatment            0            1                   1
# 99996       Obesity Treatment            0            0                   1
# 99997       Obesity Treatment            0            0                   1
# 99998         Routine Checkup            1            1                   1
# 99999       Obesity Treatment            1            0                   1
#
#       ER_VISIT_FLAG IS_URGENT_CARE_VISIT  IS_PREVENTIVE_VISIT  IP_ADMIT_INC
# 0                 0                    1                    1             1
# 1                 0                    0                    1             1
# 2                 0                    1                    0             1
# 3                 0                    0                    0             0
# 4                 0                    1                    0             0
# ...             ...                  ...                  ...           ...
# 99995             1                    1                    0             1
# 99996             0                    1                    0             0
# 99997             1                    1                    1             1
# 99998             0                    0                    0             0
# 99999             1                    1                    0             1
#
# [100000 rows x 25 columns]

# %%
rx
# Out:
#        RX_CLAIM_ID  MEMBER_ID  PAID_DATE  DAYS SERVICE_DATE  \
# 0                1      18180 2023-02-10    60   2023-01-25
# 1                2      13277 2021-08-29    30   2024-07-10
# 2                3      12610 2024-12-02    60   2023-12-13
# 3                4      18708 2024-11-15    60   2022-11-03
# 4                5      16682 2024-06-27    30   2024-12-28
# ...            ...        ...        ...   ...          ...
# 99995        99996      12607 2023-10-23    60   2023-05-21
# 99996        99997      14528 2021-04-11    30   2024-07-06
# 99997        99998      14138 2022-04-25    30   2022-05-31
# 99998        99999      16528 2024-03-10    90   2024-05-26
# 99999       100000      15894 2023-02-17    90   2023-04-21
#
#          DRUG_NAME_GENERIC DRUG_NAME_PREFERRED  RX_PAID_AMOUNT  \
# 0      hydrochlorothiazide           Microzide           31.73
# 1              semaglutide              Wegovy           11.59
# 2              semaglutide              Wegovy           46.64
# 3      hydrochlorothiazide           Microzide           43.10
# 4               amlodipine             Norvasc          131.72
# ...                    ...                 ...             ...
# 99995          liraglutide             Saxenda          456.91
# 99996          liraglutide             Saxenda          410.99
# 99997           lisinopril            Prinivil          236.02
# 99998            albuterol            Ventolin           82.51
# 99999           amlodipine             Norvasc          230.28
#
#        RX_SCRIPT_COUNT     ART_DRUGGRPS_L1 ART_DRUGGRPS_L2  PAID_YEAR  \
# 0                    3       Antidiabetics  ACE Inhibitors       2023
# 1                    1      Obesity Agents  ACE Inhibitors       2021
# 2                    2      Obesity Agents  ACE Inhibitors       2024
# 3                    3      Obesity Agents   Beta Blockers       2024
# 4                    2   Antihypertensives  ACE Inhibitors       2024
# ...                ...                 ...             ...        ...
# 99995                2       Antidiabetics   Beta Blockers       2023
# 99996                1       Antidiabetics  GLP-1 Agonists       2021
# 99997                2      Obesity Agents   Beta Blockers       2022
# 99998                3  Respiratory Agents        Inhalers       2024
# 99999                2      Obesity Agents  GLP-1 Agonists       2023
#
#        SERVICE_YEAR
# 0              2023
# 1              2024
# 2              2023
# 3              2022
# 4              2024
# ...             ...
# 99995          2023
# 99996          2024
# 99997          2022
# 99998          2024
# 99999          2023
#
# [100000 rows x 13 columns]

# %%
member
# Out:
#       MEMBER_ID  MEMBER_STATUS HOME_STATE MEMBER_RELATIONSHIP   GENDER  Age  \
# 0         16252              2         CA          Subscriber     Male   56
# 1         14684              3         NC    Domestic Partner     Male   73
# 2         11731              2         WA              Spouse  Unknown   71
# 3         14742              3         FL          Subscriber   Female   55
# 4         14521              1         FL          Subscriber  Unknown   39
# ...         ...            ...        ...                 ...      ...  ...
# 9995      15734              2         WA          Subscriber  Unknown   46
# 9996      15191              3         CA           Dependent     Male   15
# 9997      15390              2         NY          Subscriber  Unknown   43
# 9998      10860              1         UT           Dependent  Unknown   42
# 9999      17270              3         NY           Dependent  Unknown   71
#
#        GENERATIONS
# 0     Generation X
# 1     Baby Boomers
# 2     Baby Boomers
# 3     Generation X
# 4       Millenials
# ...            ...
# 9995  Generation X
# 9996  Generation Z
# 9997    Millenials
# 9998    Millenials
# 9999  Baby Boomers
#
# [10000 rows x 7 columns]

# %% [markdown]
# Find members that had taken a weight-loss GLP-1 in 2020 and 2021 and remove from the tables. This study looks at individuals who initiated in 2022.

# %%
# Define the drugs to filter out
drugs_to_remove = ['Wegovy', 'Saxenda', 'Zepbound']

# Filter to find members with the specified drugs in 2021
members_to_remove = rx[((rx['SERVICE_YEAR'] == 2021) | (rx['SERVICE_YEAR'] == 2020)) & (rx['DRUG_NAME_PREFERRED'].isin(drugs_to_remove))]['MEMBER_ID'].unique()

# Remove those members from the original DataFrame
rx_members_glp_22_24 = rx[~rx['MEMBER_ID'].isin(members_to_remove)]
med_members_glp_22_24 = med[~med['MEMBER_ID'].isin(members_to_remove)]
members_glp_22_24 = member[~member['MEMBER_ID'].isin(members_to_remove)]

# %% [markdown]
# Create a view that will set up the Percentage of Days Covered (PDC) metric. Locate GLP-1s in the rx dataset and determine days filled, start and end days per script.

# %%
# Define NDCs or names of GLP-1 drugs
glp1_drugs = ['Wegovy', 'Saxenda', 'Zepbound'] 

# Step 1: Filter for GLP-1 claims only
glp1_drugs_rx = rx_members_glp_22_24[rx_members_glp_22_24['DRUG_NAME_PREFERRED'].isin(glp1_drugs)].copy()

# Step 2: Convert fill_date to datetime
glp1_drugs_rx['SERVICE_DATE'] = pd.to_datetime(glp1_drugs_rx['SERVICE_DATE'])

# Step 3: Create a column for days covered per fill
glp1_drugs_rx['END_DATE'] = glp1_drugs_rx['SERVICE_DATE'] + pd.to_timedelta(glp1_drugs_rx['DAYS'] - 1, unit='D')
glp1_drugs_rx
# Out:
#        RX_CLAIM_ID  MEMBER_ID  PAID_DATE  DAYS SERVICE_DATE DRUG_NAME_GENERIC  \
# 1                2      13277 2021-08-29    30   2024-07-10       semaglutide
# 2                3      12610 2024-12-02    60   2023-12-13       semaglutide
# 5                6      12137 2024-04-24    60   2023-06-22       liraglutide
# 10              11      15089 2022-12-19    90   2024-03-20       semaglutide
# 11              12      11357 2022-03-05    90   2022-04-18       semaglutide
# ...            ...        ...        ...   ...          ...               ...
# 99991        99992      19266 2024-01-22    30   2022-03-16       tirzepatide
# 99992        99993      13474 2022-04-26    60   2023-05-02       tirzepatide
# 99993        99994      19951 2024-06-16    60   2022-05-31       liraglutide
# 99995        99996      12607 2023-10-23    60   2023-05-21       liraglutide
# 99996        99997      14528 2021-04-11    30   2024-07-06       liraglutide
#
#       DRUG_NAME_PREFERRED  RX_PAID_AMOUNT  RX_SCRIPT_COUNT  \
# 1                  Wegovy           11.59                1
# 2                  Wegovy           46.64                2
# 5                 Saxenda           55.89                1
# 10                 Wegovy           59.59                3
# 11                 Wegovy          161.03                3
# ...                   ...             ...              ...
# 99991            Zepbound            1.32                2
# 99992            Zepbound          187.13                3
# 99993             Saxenda           68.19                3
# 99995             Saxenda          456.91                2
# 99996             Saxenda          410.99                1
#
#           ART_DRUGGRPS_L1 ART_DRUGGRPS_L2  PAID_YEAR  SERVICE_YEAR   END_DATE
# 1          Obesity Agents  ACE Inhibitors       2021          2024 2024-08-08
# 2          Obesity Agents  ACE Inhibitors       2024          2023 2024-02-10
# 5           Antidiabetics  ACE Inhibitors       2024          2023 2023-08-20
# 10          Antidiabetics   Beta Blockers       2022          2024 2024-06-17
# 11          Antidiabetics        Inhalers       2022          2022 2022-07-16
# ...                   ...             ...        ...           ...        ...
# 99991      Obesity Agents  ACE Inhibitors       2024          2022 2022-04-14
# 99992  Respiratory Agents  ACE Inhibitors       2022          2023 2023-06-30
# 99993  Respiratory Agents  GLP-1 Agonists       2024          2022 2022-07-29
# 99995       Antidiabetics   Beta Blockers       2023          2023 2023-07-19
# 99996       Antidiabetics  GLP-1 Agonists       2021          2024 2024-08-04
#
# [60000 rows x 14 columns]

# %% [markdown]
# Aggregate sum of days filled by member ID and earliest and latest service/fill dates. Determine 3 respective years from earliest service date to create a 365-day timelines to calculate PDC.

# %%
member_pdc = glp1_drugs_rx.groupby('MEMBER_ID').agg(
    min_service_date=('SERVICE_DATE', 'min'),
    max_end_date=('END_DATE', 'max'),
    covered_days = ('DAYS', 'sum')
).reset_index()

# Add 12 months for each year
for year in range(1, 4):
    member_pdc[f'min_service_date_year_{year}'] = member_pdc['min_service_date'] + pd.DateOffset(months=12 * year)

member_pdc
# Out:
#       MEMBER_ID min_service_date max_end_date  covered_days  \
# 0         10000       2023-04-09   2024-12-21           270
# 1         10001       2022-01-14   2025-01-18           540
# 2         10002       2022-02-07   2024-12-30           660
# 3         10003       2022-12-17   2025-02-28           300
# 4         10004       2022-02-11   2024-09-11           600
# ...         ...              ...          ...           ...
# 9972      19995       2022-03-28   2024-12-30           210
# 9973      19996       2023-06-02   2024-09-29            60
# 9974      19997       2022-01-03   2025-03-29           780
# 9975      19998       2022-05-02   2023-05-11           150
# 9976      19999       2022-02-22   2024-11-30           810
#
#      min_service_date_year_1 min_service_date_year_2 min_service_date_year_3
# 0                 2024-04-09              2025-04-09              2026-04-09
# 1                 2023-01-14              2024-01-14              2025-01-14
# 2                 2023-02-07              2024-02-07              2025-02-07
# 3                 2023-12-17              2024-12-17              2025-12-17
# 4                 2023-02-11              2024-02-11              2025-02-11
# ...                      ...                     ...                     ...
# 9972              2023-03-28              2024-03-28              2025-03-28
# 9973              2024-06-02              2025-06-02              2026-06-02
# 9974              2023-01-03              2024-01-03              2025-01-03
# 9975              2023-05-02              2024-05-02              2025-05-02
# 9976              2023-02-22              2024-02-22              2025-02-22
#
# [9977 rows x 7 columns]

# %% [markdown]
# Only keep members that had earliest script dates in 2022.

# %%
members_2022 = member_pdc[member_pdc['min_service_date'] < '2023']
members_2022
# Out:
#       MEMBER_ID min_service_date max_end_date  covered_days  \
# 1         10001       2022-01-14   2025-01-18           540
# 2         10002       2022-02-07   2024-12-30           660
# 3         10003       2022-12-17   2025-02-28           300
# 4         10004       2022-02-11   2024-09-11           600
# 5         10005       2022-01-07   2024-10-04           810
# ...         ...              ...          ...           ...
# 9971      19994       2022-07-21   2024-05-03           450
# 9972      19995       2022-03-28   2024-12-30           210
# 9974      19997       2022-01-03   2025-03-29           780
# 9975      19998       2022-05-02   2023-05-11           150
# 9976      19999       2022-02-22   2024-11-30           810
#
#      min_service_date_year_1 min_service_date_year_2 min_service_date_year_3
# 1                 2023-01-14              2024-01-14              2025-01-14
# 2                 2023-02-07              2024-02-07              2025-02-07
# 3                 2023-12-17              2024-12-17              2025-12-17
# 4                 2023-02-11              2024-02-11              2025-02-11
# 5                 2023-01-07              2024-01-07              2025-01-07
# ...                      ...                     ...                     ...
# 9971              2023-07-21              2024-07-21              2025-07-21
# 9972              2023-03-28              2024-03-28              2025-03-28
# 9974              2023-01-03              2024-01-03              2025-01-03
# 9975              2023-05-02              2024-05-02              2025-05-02
# 9976              2023-02-22              2024-02-22              2025-02-22
#
# [8676 rows x 7 columns]

# %%
# Initialize a dictionary to store results
results = []

# Loop through each member and calculate covered days
for index, member in members_2022.iterrows():
    member_id = member['MEMBER_ID']
    
    # Filter rx_df for claims before year 1 and year 2
    covered_days_year_1 = glp1_drugs_rx[(glp1_drugs_rx['MEMBER_ID'] == member_id) & 
                                 (glp1_drugs_rx['SERVICE_DATE'] < member['min_service_date_year_1'])]['DAYS'].sum()
    
    covered_days_year_2 = glp1_drugs_rx[(glp1_drugs_rx['MEMBER_ID'] == member_id) & 
                                 ((glp1_drugs_rx['SERVICE_DATE'] > member['min_service_date_year_1']) & (glp1_drugs_rx['SERVICE_DATE'] < member['min_service_date_year_2']))]['DAYS'].sum()
    
    # Append results
    results.append({
        'MEMBER_ID': member_id,
        'covered_days_year_1': covered_days_year_1,
        'covered_days_year_2': covered_days_year_2
    })

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#       MEMBER_ID  covered_days_year_1  covered_days_year_2
# 0         10001                  150                  180
# 1         10002                  180                  330
# 2         10003                  150                   90
# 3         10004                  300                  270
# 4         10005                  150                  450
# ...         ...                  ...                  ...
# 8671      19994                  300                  150
# 8672      19995                   90                   60
# 8673      19997                  150                  180
# 8674      19998                  150                    0
# 8675      19999                  390                  360
#
# [8676 rows x 3 columns]

# %%
members_2022_cvd = members_2022.merge(results_df, on='MEMBER_ID')
members_2022_cvd.drop(columns=['covered_days', 'min_service_date_year_3'], inplace=True)
members_2022_cvd['PDC1'] = members_2022_cvd['covered_days_year_1']/365
members_2022_cvd['PDC2'] = members_2022_cvd['covered_days_year_2']/365
members_2022_cvd
# Out:
#       MEMBER_ID min_service_date max_end_date min_service_date_year_1  \
# 0         10001       2022-01-14   2025-01-18              2023-01-14
# 1         10002       2022-02-07   2024-12-30              2023-02-07
# 2         10003       2022-12-17   2025-02-28              2023-12-17
# 3         10004       2022-02-11   2024-09-11              2023-02-11
# 4         10005       2022-01-07   2024-10-04              2023-01-07
# ...         ...              ...          ...                     ...
# 8671      19994       2022-07-21   2024-05-03              2023-07-21
# 8672      19995       2022-03-28   2024-12-30              2023-03-28
# 8673      19997       2022-01-03   2025-03-29              2023-01-03
# 8674      19998       2022-05-02   2023-05-11              2023-05-02
# 8675      19999       2022-02-22   2024-11-30              2023-02-22
#
#      min_service_date_year_2  covered_days_year_1  covered_days_year_2  \
# 0                 2024-01-14                  150                  180
# 1                 2024-02-07                  180                  330
# 2                 2024-12-17                  150                   90
# 3                 2024-02-11                  300                  270
# 4                 2024-01-07                  150                  450
# ...                      ...                  ...                  ...
# 8671              2024-07-21                  300                  150
# 8672              2024-03-28                   90                   60
# 8673              2024-01-03                  150                  180
# 8674              2024-05-02                  150                    0
# 8675              2024-02-22                  390                  360
#
#           PDC1      PDC2
# 0     0.410959  0.493151
# 1     0.493151  0.904110
# 2     0.410959  0.246575
# 3     0.821918  0.739726
# 4     0.410959  1.232877
# ...        ...       ...
# 8671  0.821918  0.410959
# 8672  0.246575  0.164384
# 8673  0.410959  0.493151
# 8674  0.410959  0.000000
# 8675  1.068493  0.986301
#
# [8676 rows x 9 columns]

# %%
members_2022_cvd.describe()
# Out:
#           MEMBER_ID               min_service_date  \
# count   8676.000000                           8676
# mean   14992.325380  2022-05-06 00:30:42.323651584
# min    10001.000000            2022-01-01 00:00:00
# 25%    12471.750000            2022-02-14 00:00:00
# 50%    14994.500000            2022-04-15 00:00:00
# 75%    17506.250000            2022-07-10 00:00:00
# max    19999.000000            2022-12-31 00:00:00
# std     2892.197875                            NaN
#
#                         max_end_date        min_service_date_year_1  \
# count                           8676                           8676
# mean   2024-08-30 00:54:26.390041344  2023-05-06 00:30:42.323651328
# min              2022-02-04 00:00:00            2023-01-01 00:00:00
# 25%              2024-06-19 00:00:00            2023-02-14 00:00:00
# 50%              2024-10-23 00:00:00            2023-04-15 00:00:00
# 75%              2025-01-06 00:00:00            2023-07-10 00:00:00
# max              2025-03-30 00:00:00            2023-12-31 00:00:00
# std                              NaN                            NaN
#
#              min_service_date_year_2  covered_days_year_1  \
# count                           8676          8676.000000
# mean   2024-05-05 16:59:45.062240768           179.253112
# min              2024-01-01 00:00:00            30.000000
# 25%              2024-02-14 00:00:00           120.000000
# 50%              2024-04-15 00:00:00           180.000000
# 75%              2024-07-10 00:00:00           240.000000
# max              2024-12-31 00:00:00           750.000000
# std                              NaN            93.976489
#
#        covered_days_year_2         PDC1         PDC2
# count          8676.000000  8676.000000  8676.000000
# mean            119.076763     0.491104     0.326238
# min               0.000000     0.082192     0.000000
# 25%              60.000000     0.328767     0.164384
# 50%              90.000000     0.493151     0.246575
# 75%             180.000000     0.657534     0.493151
# max             630.000000     2.054795     1.726027
# std              90.309430     0.257470     0.247423

# %%
members_65 = members_2022_cvd[(members_2022_cvd['PDC1'] > 0.65) & (members_2022_cvd['PDC2'] > 0.65)]
members_65
# Out:
#       MEMBER_ID min_service_date max_end_date min_service_date_year_1  \
# 3         10004       2022-02-11   2024-09-11              2023-02-11
# 17        10019       2022-01-27   2025-01-29              2023-01-27
# 41        10048       2022-01-10   2025-03-08              2023-01-10
# 48        10057       2022-09-09   2025-02-26              2023-09-09
# 67        10079       2022-01-17   2024-10-31              2023-01-17
# ...         ...              ...          ...                     ...
# 8534      19833       2022-03-03   2025-03-07              2023-03-03
# 8562      19865       2022-04-29   2024-04-30              2023-04-29
# 8580      19885       2022-01-18   2024-01-24              2023-01-18
# 8651      19970       2022-01-12   2023-09-23              2023-01-12
# 8675      19999       2022-02-22   2024-11-30              2023-02-22
#
#      min_service_date_year_2  covered_days_year_1  covered_days_year_2  \
# 3                 2024-02-11                  300                  270
# 17                2024-01-27                  300                  270
# 41                2024-01-10                  270                  300
# 48                2024-09-09                  270                  300
# 67                2024-01-17                  390                  270
# ...                      ...                  ...                  ...
# 8534              2024-03-03                  240                  240
# 8562              2024-04-29                  300                  270
# 8580              2024-01-18                  300                  240
# 8651              2024-01-12                  240                  270
# 8675              2024-02-22                  390                  360
#
#           PDC1      PDC2
# 3     0.821918  0.739726
# 17    0.821918  0.739726
# 41    0.739726  0.821918
# 48    0.739726  0.821918
# 67    1.068493  0.739726
# ...        ...       ...
# 8534  0.657534  0.657534
# 8562  0.821918  0.739726
# 8580  0.821918  0.657534
# 8651  0.657534  0.739726
# 8675  1.068493  0.986301
#
# [317 rows x 9 columns]

# %%
members_65.describe()
# Out:
#           MEMBER_ID               min_service_date  \
# count    317.000000                            317
# mean   14788.668770  2022-05-02 01:49:01.324921088
# min    10004.000000            2022-01-02 00:00:00
# 25%    12236.000000            2022-02-06 00:00:00
# 50%    14925.000000            2022-04-06 00:00:00
# 75%    17187.000000            2022-07-02 00:00:00
# max    19999.000000            2022-12-27 00:00:00
# std     2882.985403                            NaN
#
#                         max_end_date        min_service_date_year_1  \
# count                            317                            317
# mean   2024-10-06 02:20:49.211356416  2023-05-02 01:49:01.324921088
# min              2023-09-23 00:00:00            2023-01-02 00:00:00
# 25%              2024-07-28 00:00:00            2023-02-06 00:00:00
# 50%              2024-11-08 00:00:00            2023-04-06 00:00:00
# 75%              2025-01-12 00:00:00            2023-07-02 00:00:00
# max              2025-03-28 00:00:00            2023-12-27 00:00:00
# std                              NaN                            NaN
#
#              min_service_date_year_2  covered_days_year_1  \
# count                            317           317.000000
# mean   2024-05-01 17:38:25.362776064           301.230284
# min              2024-01-02 00:00:00           240.000000
# 25%              2024-02-06 00:00:00           240.000000
# 50%              2024-04-06 00:00:00           270.000000
# 75%              2024-07-02 00:00:00           330.000000
# max              2024-12-27 00:00:00           630.000000
# std                              NaN            68.520074
#
#        covered_days_year_2        PDC1        PDC2
# count           317.000000  317.000000  317.000000
# mean            284.384858    0.825288    0.779137
# min             240.000000    0.657534    0.657534
# 25%             240.000000    0.657534    0.657534
# 50%             270.000000    0.739726    0.739726
# 75%             300.000000    0.904110    0.821918
# max             630.000000    1.726027    1.726027
# std              57.208398    0.187726    0.156735

# %%
med_agg = med_members_glp_22_24.pivot_table(index='MEMBER_ID', columns='PAID_YEAR', values='MEDICAL_PAID_AMOUNT', aggfunc='sum')
med_agg.reset_index(inplace=True)
med_agg.columns.name = None
med_agg.columns = [f"{col}" if col != 'PAID_YEAR' else 'PAID_YEAR' for col in med_agg.columns]
med_agg.rename(columns={'2021': 'Med_2021', '2022': 'Med_2022', '2023': 'Med_2023', '2024': 'Med_2024'}, inplace=True)
med_agg1 = med_agg
med_agg1
# Out:
#       MEMBER_ID  Med_2021  Med_2022  Med_2023  Med_2024
# 0         10000    767.16     74.21    418.39      8.22
# 1         10001    181.25   1207.51    737.43    924.46
# 2         10002    381.58    494.66    406.07     91.55
# 3         10003       NaN    231.70       NaN    411.31
# 4         10004   1022.38    872.68   1329.39    689.23
# ...         ...       ...       ...       ...       ...
# 9995      19995    146.98    156.59    385.34       NaN
# 9996      19996       NaN    459.20    145.45       NaN
# 9997      19997    231.15    298.27   1056.58   1452.52
# 9998      19998    965.03       NaN    588.53    260.33
# 9999      19999   1169.61   2321.26   1163.57    736.25
#
# [10000 rows x 5 columns]

# %%
# Define inflation rates (as factors)
inflation_factors = {
    2021: 1.175, 
    2022: 1.117,   
    2023: 1.069, 
    2024: 1
}

# Normalize employer paid amounts for inflation
for year, factor in inflation_factors.items():
    column_name = f'Med_{year}'
    med_agg[column_name] = med_agg[column_name] * factor
med_agg
# Out:
#       MEMBER_ID    Med_2021    Med_2022    Med_2023  Med_2024
# 0         10000   901.41300    82.89257   447.25891      8.22
# 1         10001   212.96875  1348.78867   788.31267    924.46
# 2         10002   448.35650   552.53522   434.08883     91.55
# 3         10003         NaN   258.80890         NaN    411.31
# 4         10004  1201.29650   974.78356  1421.11791    689.23
# ...         ...         ...         ...         ...       ...
# 9995      19995   172.70150   174.91103   411.92846       NaN
# 9996      19996         NaN   512.92640   155.48605       NaN
# 9997      19997   271.60125   333.16759  1129.48402   1452.52
# 9998      19998  1133.91025         NaN   629.13857    260.33
# 9999      19999  1374.29175  2592.84742  1243.85633    736.25
#
# [10000 rows x 5 columns]

# %%
med_agg['Med_Delta'] = med_agg['Med_2024'] - med_agg['Med_2021']
med_agg['Med_%_Change'] =(( med_agg['Med_2024'] - med_agg['Med_2021'])/ med_agg['Med_2021']) * 100
med_agg
# Out:
#       MEMBER_ID    Med_2021    Med_2022    Med_2023  Med_2024   Med_Delta  \
# 0         10000   901.41300    82.89257   447.25891      8.22  -893.19300
# 1         10001   212.96875  1348.78867   788.31267    924.46   711.49125
# 2         10002   448.35650   552.53522   434.08883     91.55  -356.80650
# 3         10003         NaN   258.80890         NaN    411.31         NaN
# 4         10004  1201.29650   974.78356  1421.11791    689.23  -512.06650
# ...         ...         ...         ...         ...       ...         ...
# 9995      19995   172.70150   174.91103   411.92846       NaN         NaN
# 9996      19996         NaN   512.92640   155.48605       NaN         NaN
# 9997      19997   271.60125   333.16759  1129.48402   1452.52  1180.91875
# 9998      19998  1133.91025         NaN   629.13857    260.33  -873.58025
# 9999      19999  1374.29175  2592.84742  1243.85633    736.25  -638.04175
#
#       Med_%_Change
# 0       -99.088098
# 1       334.082465
# 2       -79.580981
# 3              NaN
# 4       -42.626154
# ...            ...
# 9995           NaN
# 9996           NaN
# 9997    434.798717
# 9998    -77.041393
# 9999    -46.426950
#
# [10000 rows x 7 columns]

# %%
med_agg.fillna(0, inplace=True)

# %%
med_agg.isnull().sum()
# Out:
# MEMBER_ID       0
# Med_2021        0
# Med_2022        0
# Med_2023        0
# Med_2024        0
# Med_Delta       0
# Med_%_Change    0
# dtype: int64

# %%
import numpy as np

# Prepare the years and medical costs
years = np.array([2021, 2022, 2023, 2024])
slope_list = []

# Calculate the slope for each member
for index, row in med_agg.iterrows():
    costs = np.array([row['Med_2021'], row['Med_2022'], row['Med_2023'], row['Med_2024']])
    # Perform linear regression to get the slope
    slope, intercept = np.polyfit(years, costs, 1)  # 1 indicates linear fit
    slope_list.append(slope)

# Add the slope to the DataFrame
med_agg['Med_Slope'] = slope_list
med_agg
# Out:
#       MEMBER_ID    Med_2021    Med_2022    Med_2023  Med_2024   Med_Delta  \
# 0         10000   901.41300    82.89257   447.25891      8.22  -893.19300
# 1         10001   212.96875  1348.78867   788.31267    924.46   711.49125
# 2         10002   448.35650   552.53522   434.08883     91.55  -356.80650
# 3         10003     0.00000   258.80890     0.00000    411.31     0.00000
# 4         10004  1201.29650   974.78356  1421.11791    689.23  -512.06650
# ...         ...         ...         ...         ...       ...         ...
# 9995      19995   172.70150   174.91103   411.92846      0.00     0.00000
# 9996      19996     0.00000   512.92640   155.48605      0.00     0.00000
# 9997      19997   271.60125   333.16759  1129.48402   1452.52  1180.91875
# 9998      19998  1133.91025     0.00000   629.13857    260.33  -873.58025
# 9999      19999  1374.29175  2592.84742  1243.85633    736.25  -638.04175
#
#       Med_%_Change   Med_Slope
# 0       -99.088098 -231.521266
# 1       334.082465  157.399775
# 2       -79.580981 -118.886589
# 3         0.000000   97.512110
# 4       -42.626154 -108.986515
# ...            ...         ...
# 9995      0.000000  -28.108707
# 9996      0.000000  -35.744035
# 9997    434.798717  433.907268
# 9998    -77.041393 -199.160218
# 9999    -46.426950 -326.311634
#
# [10000 rows x 8 columns]

# %%
rx_agg = rx_members_glp_22_24.pivot_table(index='MEMBER_ID', columns='PAID_YEAR', values='RX_PAID_AMOUNT', aggfunc='sum')
rx_agg.reset_index(inplace=True)
rx_agg.columns.name = None
rx_agg.columns = [f"{col}" if col != 'PAID_YEAR' else 'PAID_YEAR' for col in rx_agg.columns]
rx_agg.rename(columns={'2021': 'Rx_2021', '2022': 'Rx_2022', '2023': 'Rx_2023', '2024': 'Rx_2024'}, inplace=True)
rx_agg1 = rx_agg
rx_agg1
# Out:
#       MEMBER_ID  Rx_2021  Rx_2022  Rx_2023  Rx_2024
# 0         10000   171.57    17.50   656.53   582.07
# 1         10001   507.90   275.44    29.99   324.83
# 2         10002   257.12   630.90   576.03    37.71
# 3         10003   167.59   139.88   177.32   970.59
# 4         10004  1004.31   262.22   205.54   683.40
# ...         ...      ...      ...      ...      ...
# 9995      19995    71.70   221.72   371.74    75.95
# 9996      19996   593.37      NaN   216.39      NaN
# 9997      19997   802.74   842.35   413.98    83.28
# 9998      19998   356.63   124.88    94.28   880.66
# 9999      19999  1383.40   365.10   525.64   188.47
#
# [10000 rows x 5 columns]

# %%
# Define inflation rates (as factors)
rx_inflation_factors = {
    2021: 1.31, 
    2022: 1.20,   
    2023: 1.103, 
    2024: 1
}

# Normalize employer paid amounts for inflation
for year, factor in rx_inflation_factors.items():
    column_name = f'Rx_{year}'
    rx_agg[column_name] = rx_agg[column_name] * factor
rx_agg
# Out:
#       MEMBER_ID    Rx_2021   Rx_2022    Rx_2023  Rx_2024
# 0         10000   224.7567    21.000  724.15259   582.07
# 1         10001   665.3490   330.528   33.07897   324.83
# 2         10002   336.8272   757.080  635.36109    37.71
# 3         10003   219.5429   167.856  195.58396   970.59
# 4         10004  1315.6461   314.664  226.71062   683.40
# ...         ...        ...       ...        ...      ...
# 9995      19995    93.9270   266.064  410.02922    75.95
# 9996      19996   777.3147       NaN  238.67817      NaN
# 9997      19997  1051.5894  1010.820  456.61994    83.28
# 9998      19998   467.1853   149.856  103.99084   880.66
# 9999      19999  1812.2540   438.120  579.78092   188.47
#
# [10000 rows x 5 columns]

# %%
rx_agg.fillna(0, inplace=True)
rx_agg.isnull().sum()
# Out:
# MEMBER_ID    0
# Rx_2021      0
# Rx_2022      0
# Rx_2023      0
# Rx_2024      0
# dtype: int64

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
rx_agg['Rx_Delta'] = rx_agg['Rx_2024'] - rx_agg['Rx_2021']
rx_agg['Rx_%_Change'] =((rx_agg['Rx_2024'] - rx_agg['Rx_2021'])/ rx_agg['Rx_2021']) * 100
# Prepare the years and medical costs
years = np.array([2021, 2022, 2023, 2024])
slope_list = []

# Calculate the slope for each member
for index, row in rx_agg.iterrows():
    costs = np.array([row['Rx_2021'], row['Rx_2022'], row['Rx_2023'], row['Rx_2024']])
    # Perform linear regression to get the slope
    slope, intercept = np.polyfit(years, costs, 1)  # 1 indicates linear fit
    slope_list.append(slope)

# Add the slope to the DataFrame
rx_agg['Rx_Slope'] = slope_list
rx_agg
# Out:
#       MEMBER_ID  Rx_2021  Rx_2022  Rx_2023  Rx_2024  Rx_Delta  Rx_%_Change  \
# 0         10000   224.76    21.00   724.15   582.07    357.31       158.98
# 1         10001   665.35   330.53    33.08   324.83   -340.52       -51.18
# 2         10002   336.83   757.08   635.36    37.71   -299.12       -88.80
# 3         10003   219.54   167.86   195.58   970.59    751.05       342.10
# 4         10004  1315.65   314.66   226.71   683.40   -632.25       -48.06
# ...         ...      ...      ...      ...      ...       ...          ...
# 9995      19995    93.93   266.06   410.03    75.95    -17.98       -19.14
# 9996      19996   777.31     0.00   238.68     0.00   -777.31      -100.00
# 9997      19997  1051.59  1010.82   456.62    83.28   -968.31       -92.08
# 9998      19998   467.19   149.86   103.99   880.66    413.47        88.50
# 9999      19999  1812.25   438.12   579.78   188.47  -1623.78       -89.60
#
#       Rx_Slope
# 0       177.51
# 1      -131.90
# 2      -101.91
# 3       228.09
# 4      -198.47
# ...        ...
# 9995      9.00
# 9996   -209.33
# 9997   -345.91
# 9998    119.46
# 9999   -472.97
#
# [10000 rows x 8 columns]

# %%
rx_agg.replace(np.inf, 0, inplace=True)
rx_agg
# Out:
#       MEMBER_ID  Rx_2021  Rx_2022  Rx_2023  Rx_2024  Rx_Delta  Rx_%_Change  \
# 0         10000   224.76    21.00   724.15   582.07    357.31       158.98
# 1         10001   665.35   330.53    33.08   324.83   -340.52       -51.18
# 2         10002   336.83   757.08   635.36    37.71   -299.12       -88.80
# 3         10003   219.54   167.86   195.58   970.59    751.05       342.10
# 4         10004  1315.65   314.66   226.71   683.40   -632.25       -48.06
# ...         ...      ...      ...      ...      ...       ...          ...
# 9995      19995    93.93   266.06   410.03    75.95    -17.98       -19.14
# 9996      19996   777.31     0.00   238.68     0.00   -777.31      -100.00
# 9997      19997  1051.59  1010.82   456.62    83.28   -968.31       -92.08
# 9998      19998   467.19   149.86   103.99   880.66    413.47        88.50
# 9999      19999  1812.25   438.12   579.78   188.47  -1623.78       -89.60
#
#       Rx_Slope
# 0       177.51
# 1      -131.90
# 2      -101.91
# 3       228.09
# 4      -198.47
# ...        ...
# 9995      9.00
# 9996   -209.33
# 9997   -345.91
# 9998    119.46
# 9999   -472.97
#
# [10000 rows x 8 columns]

# %%
member_mrg = members_glp_22_24.merge(med_agg, on='MEMBER_ID')
member_mrg = member_mrg.merge(rx_agg, on='MEMBER_ID')                                     
member_mrg
# Out:
#       MEMBER_ID  MEMBER_STATUS HOME_STATE MEMBER_RELATIONSHIP   GENDER  Age  \
# 0         16252              2         CA          Subscriber     Male   56
# 1         14684              3         NC    Domestic Partner     Male   73
# 2         11731              2         WA              Spouse  Unknown   71
# 3         14742              3         FL          Subscriber   Female   55
# 4         14521              1         FL          Subscriber  Unknown   39
# ...         ...            ...        ...                 ...      ...  ...
# 9995      15734              2         WA          Subscriber  Unknown   46
# 9996      15191              3         CA           Dependent     Male   15
# 9997      15390              2         NY          Subscriber  Unknown   43
# 9998      10860              1         UT           Dependent  Unknown   42
# 9999      17270              3         NY           Dependent  Unknown   71
#
#        GENERATIONS  Med_2021  Med_2022  Med_2023  ...  Med_Delta  \
# 0     Generation X   1005.98    837.98    403.64  ...    -463.05
# 1     Baby Boomers   1325.12    489.37   1008.46  ...    -469.25
# 2     Baby Boomers     43.49    113.36   1067.75  ...       5.46
# 3     Generation X    226.05    565.43    971.43  ...    1156.00
# 4       Millenials    635.18    341.87     67.05  ...       0.00
# ...            ...       ...       ...       ...  ...        ...
# 9995  Generation X     17.95    763.77    110.36  ...     249.74
# 9996  Generation Z     75.98    488.50    103.93  ...     476.38
# 9997    Millenials    982.12    153.24    105.23  ...    -846.67
# 9998    Millenials     16.24    263.03     25.43  ...     631.05
# 9999  Baby Boomers   1015.66    180.13    798.82  ...     -78.49
#
#       Med_%_Change  Med_Slope  Rx_2021  Rx_2022  Rx_2023  Rx_2024  Rx_Delta  \
# 0           -46.03    -182.35   856.10   712.49  1120.21   151.37   -704.73
# 1           -35.41     -88.87   536.31     6.46   820.23   919.51    383.20
# 2            12.56      97.08   698.10   121.57   217.68   167.41   -530.69
# 3           511.40     387.40   614.34     0.00   970.97   289.90   -324.44
# 4             0.00    -218.04  1253.57   462.85     3.85   470.96   -782.61
# ...            ...        ...      ...      ...      ...      ...       ...
# 9995       1390.98       9.58  1178.53    58.45     5.34   704.52   -474.01
# 9996        627.02     104.46   184.19    61.50  1137.34   766.86    582.67
# 9997        -86.21    -258.80    40.52   283.22   370.98   151.55    111.03
# 9998       3886.14     165.56   244.88   468.73    70.92   177.34    -67.54
# 9999         -7.73      38.32  1030.34   682.30   112.24  1430.13    399.79
#
#       Rx_%_Change  Rx_Slope
# 0          -82.32   -170.65
# 1           71.45    196.34
# 2          -76.02   -149.60
# 3          -52.81     -0.23
# 4          -62.43   -280.68
# ...           ...       ...
# 9995       -40.22   -147.51
# 9996       316.35    282.39
# 9997       274.03     42.09
# 9998       -27.58    -60.04
# 9999        38.80     62.93
#
# [10000 rows x 21 columns]

# %%
member1 = member_mrg.drop(columns=['MEMBER_STATUS'])
member1
# Out:
#       MEMBER_ID HOME_STATE MEMBER_RELATIONSHIP   GENDER  Age   GENERATIONS  \
# 0         16252         CA          Subscriber     Male   56  Generation X
# 1         14684         NC    Domestic Partner     Male   73  Baby Boomers
# 2         11731         WA              Spouse  Unknown   71  Baby Boomers
# 3         14742         FL          Subscriber   Female   55  Generation X
# 4         14521         FL          Subscriber  Unknown   39    Millenials
# ...         ...        ...                 ...      ...  ...           ...
# 9995      15734         WA          Subscriber  Unknown   46  Generation X
# 9996      15191         CA           Dependent     Male   15  Generation Z
# 9997      15390         NY          Subscriber  Unknown   43    Millenials
# 9998      10860         UT           Dependent  Unknown   42    Millenials
# 9999      17270         NY           Dependent  Unknown   71  Baby Boomers
#
#       Med_2021  Med_2022  Med_2023  Med_2024  Med_Delta  Med_%_Change  \
# 0      1005.98    837.98    403.64    542.93    -463.05        -46.03
# 1      1325.12    489.37   1008.46    855.87    -469.25        -35.41
# 2        43.49    113.36   1067.75     48.95       5.46         12.56
# 3       226.05    565.43    971.43   1382.05    1156.00        511.40
# 4       635.18    341.87     67.05      0.00       0.00          0.00
# ...        ...       ...       ...       ...        ...           ...
# 9995     17.95    763.77    110.36    267.69     249.74       1390.98
# 9996     75.98    488.50    103.93    552.36     476.38        627.02
# 9997    982.12    153.24    105.23    135.45    -846.67        -86.21
# 9998     16.24    263.03     25.43    647.29     631.05       3886.14
# 9999   1015.66    180.13    798.82    937.17     -78.49         -7.73
#
#       Med_Slope  Rx_2021  Rx_2022  Rx_2023  Rx_2024  Rx_Delta  Rx_%_Change  \
# 0       -182.35   856.10   712.49  1120.21   151.37   -704.73       -82.32
# 1        -88.87   536.31     6.46   820.23   919.51    383.20        71.45
# 2         97.08   698.10   121.57   217.68   167.41   -530.69       -76.02
# 3        387.40   614.34     0.00   970.97   289.90   -324.44       -52.81
# 4       -218.04  1253.57   462.85     3.85   470.96   -782.61       -62.43
# ...         ...      ...      ...      ...      ...       ...          ...
# 9995       9.58  1178.53    58.45     5.34   704.52   -474.01       -40.22
# 9996     104.46   184.19    61.50  1137.34   766.86    582.67       316.35
# 9997    -258.80    40.52   283.22   370.98   151.55    111.03       274.03
# 9998     165.56   244.88   468.73    70.92   177.34    -67.54       -27.58
# 9999      38.32  1030.34   682.30   112.24  1430.13    399.79        38.80
#
#       Rx_Slope
# 0      -170.65
# 1       196.34
# 2      -149.60
# 3        -0.23
# 4      -280.68
# ...        ...
# 9995   -147.51
# 9996    282.39
# 9997     42.09
# 9998    -60.04
# 9999     62.93
#
# [10000 rows x 20 columns]

# %%
member1.HOME_STATE.value_counts()
# Out:
# HOME_STATE
# NY    1051
# IL    1030
# CA    1005
# FL     998
# WA     997
# UT     995
# PA     993
# TX     988
# CO     985
# NC     958
# Name: count, dtype: int64

# %%
# Define the states to keep
states_to_keep = ['NC', 'PA', 'TX', 'NJ', 'MS', 'OH', 'MI']
member1['HOME_STATE'] = member1['HOME_STATE'].apply(lambda x: x if x in states_to_keep else 'OTHER')
member1
# Out:
#       MEMBER_ID HOME_STATE MEMBER_RELATIONSHIP   GENDER  Age   GENERATIONS  \
# 0         16252      OTHER          Subscriber     Male   56  Generation X
# 1         14684         NC    Domestic Partner     Male   73  Baby Boomers
# 2         11731      OTHER              Spouse  Unknown   71  Baby Boomers
# 3         14742      OTHER          Subscriber   Female   55  Generation X
# 4         14521      OTHER          Subscriber  Unknown   39    Millenials
# ...         ...        ...                 ...      ...  ...           ...
# 9995      15734      OTHER          Subscriber  Unknown   46  Generation X
# 9996      15191      OTHER           Dependent     Male   15  Generation Z
# 9997      15390      OTHER          Subscriber  Unknown   43    Millenials
# 9998      10860      OTHER           Dependent  Unknown   42    Millenials
# 9999      17270      OTHER           Dependent  Unknown   71  Baby Boomers
#
#       Med_2021  Med_2022  Med_2023  Med_2024  Med_Delta  Med_%_Change  \
# 0      1005.98    837.98    403.64    542.93    -463.05        -46.03
# 1      1325.12    489.37   1008.46    855.87    -469.25        -35.41
# 2        43.49    113.36   1067.75     48.95       5.46         12.56
# 3       226.05    565.43    971.43   1382.05    1156.00        511.40
# 4       635.18    341.87     67.05      0.00       0.00          0.00
# ...        ...       ...       ...       ...        ...           ...
# 9995     17.95    763.77    110.36    267.69     249.74       1390.98
# 9996     75.98    488.50    103.93    552.36     476.38        627.02
# 9997    982.12    153.24    105.23    135.45    -846.67        -86.21
# 9998     16.24    263.03     25.43    647.29     631.05       3886.14
# 9999   1015.66    180.13    798.82    937.17     -78.49         -7.73
#
#       Med_Slope  Rx_2021  Rx_2022  Rx_2023  Rx_2024  Rx_Delta  Rx_%_Change  \
# 0       -182.35   856.10   712.49  1120.21   151.37   -704.73       -82.32
# 1        -88.87   536.31     6.46   820.23   919.51    383.20        71.45
# 2         97.08   698.10   121.57   217.68   167.41   -530.69       -76.02
# 3        387.40   614.34     0.00   970.97   289.90   -324.44       -52.81
# 4       -218.04  1253.57   462.85     3.85   470.96   -782.61       -62.43
# ...         ...      ...      ...      ...      ...       ...          ...
# 9995       9.58  1178.53    58.45     5.34   704.52   -474.01       -40.22
# 9996     104.46   184.19    61.50  1137.34   766.86    582.67       316.35
# 9997    -258.80    40.52   283.22   370.98   151.55    111.03       274.03
# 9998     165.56   244.88   468.73    70.92   177.34    -67.54       -27.58
# 9999      38.32  1030.34   682.30   112.24  1430.13    399.79        38.80
#
#       Rx_Slope
# 0      -170.65
# 1       196.34
# 2      -149.60
# 3        -0.23
# 4      -280.68
# ...        ...
# 9995   -147.51
# 9996    282.39
# 9997     42.09
# 9998    -60.04
# 9999     62.93
#
# [10000 rows x 20 columns]

# %%
med.columns
# Out:
# Index(['MEDICAL_CLAIM_ID', 'MEMBER_ID', 'PAID_DATE', 'PAID_YEAR',
#        'SERVICE_DATE', 'SERVICE_YEAR', 'MEDICAL_PAID_AMOUNT',
#        'IS_TELEMEDICINE', 'IS_ER_AVOIDABLE', 'PRIMARY_DX', 'PROCEDURE_DESC',
#        'ARTTOS_V2_L1', 'ARTTOS_V2_L3', 'DX_IS_CHRONIC', 'ICD10_CHAPTER',
#        'ICD10_CATEGORY', 'ICD10_SECTION', 'MEG_EPISODE_DESCRIPTION',
#        'OP_SURG_INC', 'IS_PCP_VISIT', 'INCLUDED_SPECIALIST', 'ER_VISIT_FLAG',
#        'IS_URGENT_CARE_VISIT', 'IS_PREVENTIVE_VISIT', 'IP_ADMIT_INC'],
#       dtype='object')

# %%
med_util = med.groupby('MEMBER_ID').agg({
    'DX_IS_CHRONIC': 'max',
    'ER_VISIT_FLAG': 'sum',
    'IS_PCP_VISIT': 'sum',
    'IS_URGENT_CARE_VISIT': 'sum',
    'IS_PREVENTIVE_VISIT': 'sum',
    'IP_ADMIT_INC': 'sum'
}).reset_index()
med_util
# Out:
#       MEMBER_ID  DX_IS_CHRONIC  ER_VISIT_FLAG  IS_PCP_VISIT  \
# 0         10000              1              5             5
# 1         10001              1              7             7
# 2         10002              1              6             5
# 3         10003              1              3             5
# 4         10004              1              8             4
# ...         ...            ...            ...           ...
# 9995      19995              1              4             5
# 9996      19996              1              4             5
# 9997      19997              1              9             5
# 9998      19998              1              5             4
# 9999      19999              1              8             8
#
#       IS_URGENT_CARE_VISIT  IS_PREVENTIVE_VISIT  IP_ADMIT_INC
# 0                        5                    5             4
# 1                       10                    5             6
# 2                        7                    6             6
# 3                        5                    5             3
# 4                       11                    8             8
# ...                    ...                  ...           ...
# 9995                     6                    4             5
# 9996                     4                    2             3
# 9997                    11                    8             4
# 9998                     7                    3             5
# 9999                     7                   14            13
#
# [10000 rows x 7 columns]

# %%
episodes = med.ICD10_CHAPTER.value_counts()
episodes.head(10)
# Out:
# ICD10_CHAPTER
# Digestive      33490
# Circulatory    33285
# Endocrine      33225
# Name: count, dtype: int64

# %%
episodes_cost = med.groupby('ICD10_CHAPTER')['MEDICAL_PAID_AMOUNT'].sum().reset_index()
episodes_cost.sort_values(by='MEDICAL_PAID_AMOUNT', ascending=False)
# Out:
#   ICD10_CHAPTER  MEDICAL_PAID_AMOUNT
# 2     Endocrine           6703577.36
# 1     Digestive           6692078.46
# 0   Circulatory           6655438.42

# %%
episodes_to_keep = ['Diseases of the musculoskeletal system and connective tissue', 'Neoplasms', 'Diseases of the digestive system', 
                    'Diseases of the circulatory system', 'Diseases of the circulatory system', 'Diseases of the genitourinary system',
                   'Diseases of the nervous system', 'Mental, Behavioral and Neurodevelopmental disorders']
med1 = med
med1['ICD10_CHAPTER'] = med['ICD10_CHAPTER'].apply(lambda x: x if x in episodes_to_keep else 'OTHER')

# %%
med_meg = pd.pivot_table(
    med1,
    values='MEDICAL_PAID_AMOUNT',
    index='MEMBER_ID',
    columns='ICD10_CHAPTER',
    aggfunc='sum',
    fill_value=0
)
med_meg.reset_index()
med_meg.columns.name = None
med_meg.drop(columns='OTHER', inplace=True)
med_meg
# Out:
# Empty DataFrame
# Columns: []
# Index: [10000, 10001, 10002, 10003, 10004, 10005, 10006, 10007, 10008, 10009, 10010, 10011, 10012, 10013, 10014, 10015, 10016, 10017, 10018, 10019, 10020, 10021, 10022, 10023, 10024, 10025, 10026, 10027, 10028, 10029, 10030, 10031, 10032, 10033, 10034, 10035, 10036, 10037, 10038, 10039, 10040, 10041, 10042, 10043, 10044, 10045, 10046, 10047, 10048, 10049, 10050, 10051, 10052, 10053, 10054, 10055, 10056, 10057, 10058, 10059, 10060, 10061, 10062, 10063, 10064, 10065, 10066, 10067, 10068, 10069, 10070, 10071, 10072, 10073, 10074, 10075, 10076, 10077, 10078, 10079, 10080, 10081, 10082, 10083, 10084, 10085, 10086, 10087, 10088, 10089, 10090, 10091, 10092, 10093, 10094, 10095, 10096, 10097, 10098, 10099, ...]
#
# [10000 rows x 0 columns]

# %%
med_var = member1.merge(med_util, on='MEMBER_ID')
med_var = med_var.merge(med_meg, on='MEMBER_ID')
med_var.columns= med_var.columns.str.replace(' ', '_')
med_var
# Out:
#       MEMBER_ID HOME_STATE MEMBER_RELATIONSHIP   GENDER  Age   GENERATIONS  \
# 0         16252      OTHER          Subscriber     Male   56  Generation X
# 1         14684         NC    Domestic Partner     Male   73  Baby Boomers
# 2         11731      OTHER              Spouse  Unknown   71  Baby Boomers
# 3         14742      OTHER          Subscriber   Female   55  Generation X
# 4         14521      OTHER          Subscriber  Unknown   39    Millenials
# ...         ...        ...                 ...      ...  ...           ...
# 9995      15734      OTHER          Subscriber  Unknown   46  Generation X
# 9996      15191      OTHER           Dependent     Male   15  Generation Z
# 9997      15390      OTHER          Subscriber  Unknown   43    Millenials
# 9998      10860      OTHER           Dependent  Unknown   42    Millenials
# 9999      17270      OTHER           Dependent  Unknown   71  Baby Boomers
#
#       Med_2021  Med_2022  Med_2023  Med_2024  ...  Rx_2024  Rx_Delta  \
# 0      1005.98    837.98    403.64    542.93  ...   151.37   -704.73
# 1      1325.12    489.37   1008.46    855.87  ...   919.51    383.20
# 2        43.49    113.36   1067.75     48.95  ...   167.41   -530.69
# 3       226.05    565.43    971.43   1382.05  ...   289.90   -324.44
# 4       635.18    341.87     67.05      0.00  ...   470.96   -782.61
# ...        ...       ...       ...       ...  ...      ...       ...
# 9995     17.95    763.77    110.36    267.69  ...   704.52   -474.01
# 9996     75.98    488.50    103.93    552.36  ...   766.86    582.67
# 9997    982.12    153.24    105.23    135.45  ...   151.55    111.03
# 9998     16.24    263.03     25.43    647.29  ...   177.34    -67.54
# 9999   1015.66    180.13    798.82    937.17  ...  1430.13    399.79
#
#       Rx_%_Change  Rx_Slope  DX_IS_CHRONIC  ER_VISIT_FLAG  IS_PCP_VISIT  \
# 0          -82.32   -170.65              1              5             5
# 1           71.45    196.34              1              6             8
# 2          -76.02   -149.60              1              4             3
# 3          -52.81     -0.23              1              7             7
# 4          -62.43   -280.68              1              4             3
# ...           ...       ...            ...            ...           ...
# 9995       -40.22   -147.51              1              8             3
# 9996       316.35    282.39              1              6             4
# 9997       274.03     42.09              1              5             2
# 9998       -27.58    -60.04              1              4             4
# 9999        38.80     62.93              1              5             9
#
#       IS_URGENT_CARE_VISIT  IS_PREVENTIVE_VISIT  IP_ADMIT_INC
# 0                        7                    8             6
# 1                        9                    6             6
# 2                        4                    2             4
# 3                        6                    6             7
# 4                        5                    2             1
# ...                    ...                  ...           ...
# 9995                     2                    5             3
# 9996                     6                    4             7
# 9997                     4                    2             2
# 9998                     3                    5             4
# 9999                     6                    5             4
#
# [10000 rows x 26 columns]

# %%
mbr = members_65['MEMBER_ID'].unique()
members65_df = med_var[med_var['MEMBER_ID'].isin(mbr)]
members65_df
# Out:
#       MEMBER_ID HOME_STATE MEMBER_RELATIONSHIP   GENDER  Age   GENERATIONS  \
# 26        11963      OTHER          Subscriber   Female   45  Generation X
# 27        18243      OTHER          Subscriber  Unknown   27  Generation Z
# 71        10799         NC           Dependent   Female   41    Millenials
# 101       15019      OTHER          Subscriber   Female   30    Millenials
# 193       12908      OTHER             Unknown     Male   59  Generation X
# ...         ...        ...                 ...      ...  ...           ...
# 9847      11306         NC           Dependent     Male   45  Generation X
# 9862      13242      OTHER           Dependent  Unknown   47  Generation X
# 9874      17858      OTHER             Unknown   Female   28    Millenials
# 9885      10502      OTHER           Dependent     Male   62  Baby Boomers
# 9944      17555         NC             Unknown     Male   32    Millenials
#
#       Med_2021  Med_2022  Med_2023  Med_2024  ...  Rx_2024  Rx_Delta  \
# 26       28.85   1064.56   1197.59    464.60  ...     0.00   -330.08
# 27     1416.37    990.81    933.74    612.60  ...   377.80   -633.70
# 71      892.10    574.75   1106.90    185.24  ...   452.59   -838.66
# 101     298.80    868.53    501.52    340.70  ...   699.66    253.42
# 193     610.51   1080.15    145.13    359.04  ...   946.00    860.08
# ...        ...       ...       ...       ...  ...      ...       ...
# 9847     91.47    445.54     54.68   1073.18  ...   236.34   -241.25
# 9862   2124.73    718.48    225.80    431.00  ...   373.21  -1127.51
# 9874    199.87     86.80    255.33   1242.55  ...   312.43    165.00
# 9885    164.14     93.19   2013.14    730.81  ...   444.10  -1075.88
# 9944    345.18    743.29   1508.46    455.46  ...     0.00  -1343.69
#
#       Rx_%_Change  Rx_Slope  DX_IS_CHRONIC  ER_VISIT_FLAG  IS_PCP_VISIT  \
# 26        -100.00    -47.70              1              6             4
# 27         -62.65   -237.08              1             11            10
# 71         -64.95   -207.92              1              8             9
# 101         56.79     35.46              1              3             7
# 193       1000.99    225.76              1              9             6
# ...           ...       ...            ...            ...           ...
# 9847       -50.51    -70.27              1              4             3
# 9862       -75.13   -378.52              1              7             6
# 9874       111.92     69.44              1              6             6
# 9885       -70.78   -341.11              1              6             7
# 9944      -100.00   -328.15              1              8             8
#
#       IS_URGENT_CARE_VISIT  IS_PREVENTIVE_VISIT  IP_ADMIT_INC
# 26                       4                    3             8
# 27                       7                   11            13
# 71                      12                    7            13
# 101                      7                    7             7
# 193                      9                    8             8
# ...                    ...                  ...           ...
# 9847                     5                    2             4
# 9862                     5                    8             4
# 9874                     4                    4             3
# 9885                     9                    3             8
# 9944                     5                    7             7
#
# [317 rows x 26 columns]

# %%
med_var.columns
# Out:
# Index(['MEMBER_ID', 'HOME_STATE', 'MEMBER_RELATIONSHIP', 'GENDER', 'Age',
#        'GENERATIONS', 'Med_2021', 'Med_2022', 'Med_2023', 'Med_2024',
#        'Med_Delta', 'Med_%_Change', 'Med_Slope', 'Rx_2021', 'Rx_2022',
#        'Rx_2023', 'Rx_2024', 'Rx_Delta', 'Rx_%_Change', 'Rx_Slope',
#        'DX_IS_CHRONIC', 'ER_VISIT_FLAG', 'IS_PCP_VISIT',
#        'IS_URGENT_CARE_VISIT', 'IS_PREVENTIVE_VISIT', 'IP_ADMIT_INC'],
#       dtype='object')

# %%
members65_df.describe()
# Out:
#        MEMBER_ID    Age  Med_2021  Med_2022  Med_2023  Med_2024  Med_Delta  \
# count     317.00 317.00    317.00    317.00    317.00    317.00     317.00
# mean    14788.67  44.64    895.03    766.87    777.16    745.83    -142.05
# std      2882.99  19.00    689.18    551.35    555.59    518.93     873.49
# min     10004.00  13.00      0.00      0.00      0.00      0.00   -3930.68
# 25%     12236.00  30.00    395.48    391.24    348.39    353.17    -670.96
# 50%     14925.00  42.00    743.15    653.39    650.96    656.74     -58.25
# 75%     17187.00  61.00   1228.06   1025.81   1061.39   1043.24     421.09
# max     19999.00  79.00   4281.97   2605.56   3229.15   2899.88    2031.63
#
#        Med_%_Change  Med_Slope  Rx_2021  ...  Rx_2024  Rx_Delta  Rx_%_Change  \
# count        317.00     317.00   317.00  ...   317.00    317.00       317.00
# mean         165.39     -43.73   726.51  ...   518.62   -207.89       143.39
# std          978.48     276.35   535.65  ...   344.60    658.49       886.15
# min          -99.41   -1117.71     0.00  ...     0.00  -3408.62      -100.00
# 25%          -59.00    -209.05   347.77  ...   252.08   -579.85       -65.89
# 50%          -10.02     -24.13   627.74  ...   444.10   -147.65       -26.72
# 75%          104.05     144.03   991.67  ...   735.71    225.04        48.93
# max        14182.68     633.90  3534.92  ...  1614.06   1240.34     11891.43
#
#        Rx_Slope  DX_IS_CHRONIC  ER_VISIT_FLAG  IS_PCP_VISIT  \
# count    317.00         317.00         317.00        317.00
# mean     -63.77           1.00           7.21          7.37
# std      207.85           0.00           2.26          2.39
# min    -1081.87           1.00           3.00          2.00
# 25%     -185.01           1.00           6.00          5.00
# 50%      -44.76           1.00           7.00          8.00
# 75%       64.64           1.00           8.00          9.00
# max      446.83           1.00          15.00         14.00
#
#        IS_URGENT_CARE_VISIT  IS_PREVENTIVE_VISIT  IP_ADMIT_INC
# count                317.00               317.00        317.00
# mean                   7.19                 7.17          7.45
# std                    2.34                 2.50          2.47
# min                    3.00                 0.00          1.00
# 25%                    5.00                 5.00          6.00
# 50%                    7.00                 7.00          7.00
# 75%                    9.00                 9.00          9.00
# max                   15.00                14.00         15.00
#
# [8 rows x 22 columns]

# %%
costs = members65_df[['MEMBER_ID', 'HOME_STATE', 'MEMBER_RELATIONSHIP', 'GENDER', 'Age',
       'GENERATIONS', 'Med_2021', 'Med_2022', 'Med_2023', 'Med_2024',
       'Med_Delta', 'Med_%_Change', 'Med_Slope', 'Rx_2021', 'Rx_2022',
       'Rx_2023', 'Rx_2024', 'Rx_Delta', 'Rx_%_Change', 'Rx_Slope']]
costs
# Out:
#       MEMBER_ID HOME_STATE MEMBER_RELATIONSHIP   GENDER  Age   GENERATIONS  \
# 26        11963      OTHER          Subscriber   Female   45  Generation X
# 27        18243      OTHER          Subscriber  Unknown   27  Generation Z
# 71        10799         NC           Dependent   Female   41    Millenials
# 101       15019      OTHER          Subscriber   Female   30    Millenials
# 193       12908      OTHER             Unknown     Male   59  Generation X
# ...         ...        ...                 ...      ...  ...           ...
# 9847      11306         NC           Dependent     Male   45  Generation X
# 9862      13242      OTHER           Dependent  Unknown   47  Generation X
# 9874      17858      OTHER             Unknown   Female   28    Millenials
# 9885      10502      OTHER           Dependent     Male   62  Baby Boomers
# 9944      17555         NC             Unknown     Male   32    Millenials
#
#       Med_2021  Med_2022  Med_2023  Med_2024  Med_Delta  Med_%_Change  \
# 26       28.85   1064.56   1197.59    464.60     435.75       1510.61
# 27     1416.37    990.81    933.74    612.60    -803.77        -56.75
# 71      892.10    574.75   1106.90    185.24    -706.86        -79.24
# 101     298.80    868.53    501.52    340.70      41.90         14.02
# 193     610.51   1080.15    145.13    359.04    -251.47        -41.19
# ...        ...       ...       ...       ...        ...           ...
# 9847     91.47    445.54     54.68   1073.18     981.71       1073.21
# 9862   2124.73    718.48    225.80    431.00   -1693.73        -79.72
# 9874    199.87     86.80    255.33   1242.55    1042.68        521.69
# 9885    164.14     93.19   2013.14    730.81     566.67        345.25
# 9944    345.18    743.29   1508.46    455.46     110.28         31.95
#
#       Med_Slope  Rx_2021  Rx_2022  Rx_2023  Rx_2024  Rx_Delta  Rx_%_Change  \
# 26       144.03   330.08   269.88   783.14     0.00   -330.08      -100.00
# 27      -246.84  1011.50  1220.08   750.40   377.80   -633.70       -62.65
# 71      -158.84  1291.25   701.95  1138.77   452.59   -838.66       -64.95
# 101      -24.13   446.24   510.94   105.28   699.66    253.42        56.79
# 193     -168.94    85.92   694.15   371.53   946.00    860.08      1000.99
# ...         ...      ...      ...      ...      ...       ...          ...
# 9847     255.43   477.59   247.18   268.23   236.34   -241.25       -50.51
# 9862    -557.39  1500.72   553.98   151.32   373.21  -1127.51       -75.13
# 9874     329.66   147.43   430.44   629.88   312.43    165.00       111.92
# 9885     362.00  1519.98   595.08   411.57   444.10  -1075.88       -70.78
# 9944     109.60  1343.69   248.82   998.36     0.00  -1343.69      -100.00
#
#       Rx_Slope
# 26      -47.70
# 27     -237.08
# 71     -207.92
# 101      35.46
# 193     225.76
# ...        ...
# 9847    -70.27
# 9862   -378.52
# 9874     69.44
# 9885   -341.11
# 9944   -328.15
#
# [317 rows x 20 columns]

# %%
costs.describe()
# Out:
#        MEMBER_ID    Age  Med_2021  Med_2022  Med_2023  Med_2024  Med_Delta  \
# count     317.00 317.00    317.00    317.00    317.00    317.00     317.00
# mean    14788.67  44.64    895.03    766.87    777.16    745.83    -142.05
# std      2882.99  19.00    689.18    551.35    555.59    518.93     873.49
# min     10004.00  13.00      0.00      0.00      0.00      0.00   -3930.68
# 25%     12236.00  30.00    395.48    391.24    348.39    353.17    -670.96
# 50%     14925.00  42.00    743.15    653.39    650.96    656.74     -58.25
# 75%     17187.00  61.00   1228.06   1025.81   1061.39   1043.24     421.09
# max     19999.00  79.00   4281.97   2605.56   3229.15   2899.88    2031.63
#
#        Med_%_Change  Med_Slope  Rx_2021  Rx_2022  Rx_2023  Rx_2024  Rx_Delta  \
# count        317.00     317.00   317.00   317.00   317.00   317.00    317.00
# mean         165.39     -43.73   726.51   601.78   587.76   518.62   -207.89
# std          978.48     276.35   535.65   459.26   415.78   344.60    658.49
# min          -99.41   -1117.71     0.00     0.00     0.00     0.00  -3408.62
# 25%          -59.00    -209.05   347.77   252.79   268.23   252.08   -579.85
# 50%          -10.02     -24.13   627.74   528.88   527.22   444.10   -147.65
# 75%          104.05     144.03   991.67   837.19   836.44   735.71    225.04
# max        14182.68     633.90  3534.92  2738.60  2269.85  1614.06   1240.34
#
#        Rx_%_Change  Rx_Slope
# count       317.00    317.00
# mean        143.39    -63.77
# std         886.15    207.85
# min        -100.00  -1081.87
# 25%         -65.89   -185.01
# 50%         -26.72    -44.76
# 75%          48.93     64.64
# max       11891.43    446.83

# %% [markdown]
# average med+rx net per member, normalized for 2024 = $11,834-1,554 = $10,280. Since 2021, employers have spent $10,280 average per member on those that have prescriptions for Wegovy, Saxenda or Zepbound for 3 years

# %%
members65_df.to_csv('glp1_members_pdc65.csv', index=False)

# %%
drugs = rx.groupby(['ART_DRUGGRPS_L1', 'ART_DRUGGRPS_L2', 'DRUG_NAME_PREFERRED'])['RX_PAID_AMOUNT'].sum().reset_index()
drugs.sort_values(by='RX_PAID_AMOUNT', ascending=False, inplace=True)
drugs
# Out:
#         ART_DRUGGRPS_L1 ART_DRUGGRPS_L2 DRUG_NAME_PREFERRED  RX_PAID_AMOUNT
# 99       Obesity Agents   Beta Blockers            Zepbound       202429.04
# 145  Respiratory Agents  GLP-1 Agonists             Saxenda       201586.64
# 138  Respiratory Agents   Beta Blockers              Wegovy       199659.79
# 95       Obesity Agents   Beta Blockers             Saxenda       197164.16
# 149  Respiratory Agents  GLP-1 Agonists            Zepbound       197089.88
# ..                  ...             ...                 ...             ...
# 91       Obesity Agents   Beta Blockers             Lipitor        46789.39
# 71    Antihypertensives        Inhalers             Lipitor        46704.27
# 127  Respiratory Agents  ACE Inhibitors            Ventolin        46424.46
# 10        Antidiabetics   Beta Blockers          Glucophage        46197.28
# 136  Respiratory Agents   Beta Blockers           Synthroid        45740.40
#
# [160 rows x 4 columns]

# %%
med.to_csv('GLP-1_Medical_PDC.csv', index=False)
